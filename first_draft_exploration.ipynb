# %% [markdown]
# # Analyzing and Predicting Employee Attrition
# - What's driving employee attrition?
# - Are certain employee types leaving more than others?
# - Why is employee attrition a problem?
#
#
# ## Overview
#
# While attrition is an inevitable part of running a business, employee turnover is an expensive, disruptive,
#
# ## Why is attrition a problem? How big of a problem?
# https://www.peoplekeep.com/blog/employee-retention-the-real-cost-of-losing-an-employee
#
# - Less than 10% is a healthy attrition
# - 2022
#
# ## Questions and hypotheses
# - What's the relationship between compensation and attrition?
# - Do employees who travel more have a higher attrition rate?
# - Are some employee demographics turning over at a higher rate?
# - Are certain departments or job roles seeing more turnover?
#
# - What's the relationship between attrition and
#
#
# ## Summary of Findings, Key Takeaways, and Recommendations
# - TODO

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import classification_report

from prepare import train_validate_test_split, drop_unnecessary_columns

# %%
filename = "employee_attrition_performance.csv"
df = pd.read_csv(filename)

# %%
df.head(3).T
# Out:
#                                         0                       1  \
# Age                                    41                      49
# Attrition                             Yes                      No
# BusinessTravel              Travel_Rarely       Travel_Frequently
# DailyRate                            1102                     279
# Department                          Sales  Research & Development
# DistanceFromHome                        1                       8
# Education                               2                       1
# EducationField              Life Sciences           Life Sciences
# EmployeeCount                           1                       1
# EmployeeNumber                          1                       2
# EnvironmentSatisfaction                 2                       3
# Gender                             Female                    Male
# HourlyRate                             94                      61
# ...

# %% [markdown]
# ## Summarize and Prep the Dataset

# %%
# Check for nulls. No nulls mean we don't need to handle them w/ this data
df.isna().sum().sum()

# %%
# Split the data before exploring
train, validate, test = train_validate_test_split(df)

# %%
df.JobRole.value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %% [markdown]
# ### Using Conditional Probability to See if I can simplify a 3 value categorical column into a boolean

# %%
# p(attrition)
x = df.Attrition.value_counts(normalize=True)[1].round(2)
f"Population probability of attrition is {x}"

# %%
# p(churn | rare_travel)
df[df.BusinessTravel == "Travel_Rarely"].Attrition.value_counts(normalize=True)["Yes"]

# %%
# p(churn | frequent_travel)
df[df.BusinessTravel == "Travel_Frequently"].Attrition.value_counts(normalize=True)

# %%
# p(attrition | Non-Travel) is 0.08
df[df.BusinessTravel == "Non-Travel"].Attrition.value_counts(normalize=True)

# %%
df.head(3).T

# %% [markdown]
# ## Preparation Steps

# %% [markdown]
# ## Pre-Processing Steps (Encoding Categorical and Scaling Numeric Columns)
# - We'll encode categories before splitting
# - We'll split into train, validate, and test here
# - We'll scale numeric columns
#     - Fit the scaler on train, transform train, validate, and test dataframes

# %%
df.columns.tolist()
